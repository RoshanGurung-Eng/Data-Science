# %%
print("How are you??")
print("wir gehts es dir??")
# Out:
# How are you??
# wir gehts es dir??

# %%
fruits = ["apple", "banana", "cherry"]
sports = ["Football", "Cricket", "WWE"]
for x in fruits:
  print(x)

for y in sports:
  print(y)

s = [1,2,3,4,5,6]
b = [1,4,8,12]
for z in s:
  if s == 2 :
    print(s)
    print(b)
  print(z)
# Out:
# apple
# banana
# cherry
# Football
# Cricket
# WWE
# 1
# 2
# 3
# 4
# 5
# 6

# %%
print("Data Science")
