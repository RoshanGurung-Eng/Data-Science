# %%
from google import genai

# Create the client using your API key
client = genai.Client(api_key="AIzaSyCq-lLaaAALZycfE-0NE8pWTA3jCKJITqk")

prompt = """
Give a short poem by Rabindranath Tagore
"""
    
try:
    # Updated to a valid Gemini model version
    response = client.models.generate_content(
        model='gemini-2.5-flash', 
        contents=prompt
    )
    print(response.text)
except Exception as e:
    print(f"Error calling Gemini: {e}")
# Out:
# Here's a short poem by Rabindranath Tagore, expressing a profound wish:
#
# Let me not pray to be sheltered from dangers,
# but to be fearless in facing them.
# Let me not beg for the stilling of my pain,
# but for the heart to conquer it.
