# %%
print("How are you??")
# Out:
# How are you??

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)
  print(fruits)
# Out:
# apple
# ['apple', 'banana', 'cherry']
# banana
# ['apple', 'banana', 'cherry']
# cherry
# ['apple', 'banana', 'cherry']
