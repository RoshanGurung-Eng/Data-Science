# %%
print("How are you??")
# Out:
# How are you??

# %%
print("so is it still working or not")
# Out:
# so is it still working or not

# %%
print("so now its working nice ")
# Out:
# so now its working nice
