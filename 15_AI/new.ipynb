# %%
print("How are you??")
# Out:
# How are you??

# %%
fruits = ["apple", "banana", "cherry"]
sports = ["Football", "Cricket", "WWE"]
for x in fruits:
  print(x)

for y in sports:
  print(y)
# Out:
# apple
# banana
# cherry
# Football
# Cricket
# WWE
