# %%
print("How are you??")
print("wir gehts es dir??")
# Out:
# How are you??
# wir gehts es dir??

# %%
fruits = ["apple", "banana", "cherry"]
sports = ["Football", "Cricket", "WWE"]
for x in fruits:
  print(x)

for y in sports:
  print(y)

s = [1,2,3,4,5,6]
b = [1,4,8,12]
for z in s:
  if s == 2 :
    print(s)
    print(b)
  print(z)
# Out:
# apple
# banana
# cherry
# Football
# Cricket
# WWE
# 1
# 2
# 3
# 4
# 5
# 6

# %%
print("Data Science")
print("Data science is not easy ")
print("I am still not ready for my german classes")
print("German")
print("Dont give up YOU need to push yourself now or you gonna live in hell")
print("Germany!!!!!!!!!!!!!!!!")
print("Aww man")
print("Every daY SAME ROUTINE SAME PROBLEM ")
print("So any idea whats going on")
# Out:
# Data Science
# Data science is not easy
# I am still not ready for my german classes
# German
# Dont give up YOU need to push yourself now or you gonna live in hell
# Germany!!!!!!!!!!!!!!!!
# Aww man
# Every daY SAME ROUTINE SAME PROBLEM
# So any idea whats going on

# %%
print(5+5)
print(5*5)
print(5-5)
# Out:
# 10
# 25
# 0
