# %%
from google import genai
from PIL import Image

# Please remember to remove raw API keys before saving online!
client = genai.Client(api_key="AIzaSyCq-lLaaAALZycfE-0NE8pWTA3jCKJITqk")

# 1. Load your local image
# IMPORTANT: Make sure this file actually exists in your project folder!
image = Image.open('sample_image.jpg') 

# 2. Define your multimodal prompt
prompt = "Please provide a detailed description of this image and relate its mood to a poem by Rabindranath Tagore."

try:
    # 3. Fixes: Use a valid model AND send both the image and the prompt!
    response = client.models.generate_content(
        model='gemini-2.5-flash',
        contents=[image, prompt] # <-- Array containing both
    )
    print(response.text)
except Exception as e:
    print(f"Error calling Gemini: {e}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 9
#       5 client = genai.Client(api_key="AIzaSyCq-lLaaAALZycfE-0NE8pWTA3jCKJITqk")
#       7 # 1. Load your local image
#       8 # IMPORTANT: Make sure this file actually exists in your project folder!
# ----> 9 image = Image.open('sample_image.jpg')
#      11 # 2. Define your multimodal prompt
#      12 prompt = "Please provide a detailed description of this image and relate its mood to a poem by Rabindranath Tagore."
#
# File c:\Users\hp\OneDrive\Attachments\Desktop\Data Science\.venv\Lib\site-packages\PIL\Image.py:3512, in open(fp, mode, formats)
#    3510 if is_path(fp):
#    3511     filename = os.fspath(fp)
# -> 3512     fp = builtins.open(filename, "rb")
#    3513     exclusive_fp = True
#    3514 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample_image.jpg'
